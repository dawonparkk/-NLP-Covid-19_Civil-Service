# %%
import pandas as pd
import dask as dd
import pickle

# %% [markdown]
# # 불용어 제거 전처리

# %%
# 민원 text 불러오기
with open('dasan_CN.bin','rb') as f:
    df_CN = pickle.load(f)

# %% [markdown]
# #### 1차 불용어 제거

# %%
# 불용어 list
stop_word = ["민원","당직실","처리","문자","접수","신청","요청","내용","결과","담당자","종결","확인","담당","공유","신고","기관","연락처","답변",
            "공개","민원사무","대한","회신","번호","다른","처분","해당","전환","서울","서울시","일산","위원","청구인","민원인","바로",
            "계속","하심","전달","원함","매우","너무","경우","동","번","옆","위치","사람","건의","조속","번지","건","제대로","위",
            "그대로","하니","맞은편","이후","주소지","주소","알","점","첨부","응답","전송","곳","추가","관련","호","사진","전송",
            "후","쪽","위","하심","이","현장","함","부서","주변","요망","익명","발송","정도","층","사항","전화","방향","발생",
            "현재","바람","부분","제보","달라","사이","원문","소","수신","통보","통화","고함","연락","참고","전혀","방문","본인",
            "안내","물이","당직","인근","실","개인정보","관","대해","유선","문의","행정","일반","가지","접","수건","막","한번","조",
            "직접","용","주","성명","일이","하라","항상","통해","계","보고","보기","바","장","서울특별시","수가","외","자체","주무관",
            "봉","채","목","상기","부","자주","교","지난","누가","석","기존","이름","시경","일전","스","예전","누군가","당시","걸",
            "일시","대상","제목","팀","일부","얘기","이야기","음으로","두","온","파","보이지","말씀","라며","해주시","군데","감","데",
            "처","성함","지나","홍","업","참조","실제","김","이로","치","익스","지난번","가요","먼저","행","원치","웹","단","모바일",
            "콜센터","아예","터","가면","봐","원래","요즘","자꾸","플로","도로로","미리","타","첨부파일","화가","더욱","므","며","거기",
            "커서","주지","너무나","살피","갑자기","도저히","하이","응대","여러가지","안녕하십니까","도대체","이틀","보","연","제일","타고",
            "늘","읍니","움","겁","필요시","저번","가량","마길","안해","일자","애","무조건","건너","막도","중임","치가","옴","준","영",
            "수십","그동안","일로","잔뜩","달이","역시","령","버려진","홈페이지","그로","대부분","면도","골로","년전","최소한","달리",
            "중이","마련","두번","몇개","틀","진","온갖","주어","하나요","리버","로서","가까이","주로","이하","특정","생기","로만","당",
            "질","마다","년도","카","주일","이내","즉각","마주","츠","데리","귀하","란","뭔가","건가","보임","이나","힘듭니","별로",
            "달전","바길","대체","이첩","생","송","거려","이외","곳도","깜박","쉬","어서","잡","다가","야기","구함","급","가끔","면서",
            "일부러","수준","향후","대답","의거","주간","끼리","당한","는걸","가기","한참","빈","림","젠","억","씨","것임","보아",
            "원하심","지고","내지","메","힐","부디","조용원","남아","무것","주심","건대","곳곳","소가","지라","다른사람","돌이","개별",
            "마찬가지","사가","부득이","휘","필히","라바","삼","율","트","이지","널","여기저기","동쪽","항시","프레","복","머","자고",
            "광","그게","너스","이정우","제때","린다","이점","듭니","여개","규","황","성심껏","직","님","립","일주","우디","텁","만듭니",
            "접수확인","곡","종종","당부","을해","배우자","베","일신","케","납","습","셨","밀리","레","여곳","이구","고이","덜","버",
            "컬","압","숙","줌","디안","징구","워","각계","일삼","띠","에스","요소","조도","퇴","데시","혜","양경자"]

# %%
# 1차 불용어 제거
for i in range(df_CN.shape[0]) :
    if i%1000 == 0 :
        print(i)
    for j in range(len(stop_word)) : 
        try : 
            df_CN['CN'][i].remove(stop_word[j])
        except : 
            pass

# %%
with open( "df_CN_stopword.bin", "wb" ) as file:
    pickle.dump(df_CN, file)

# %%
df_CN.tail(30)

# %%
with open('CN_word_list.bin','rb') as f:
    df = pickle.load(f)

# %%
# 빈도수 기준으로 형태소 정렬 후 저장
s1 = pd.Series(df)
word_count = s1.value_counts()
word_count2 = word_count.reset_index()
word_count2.to_csv('dasan_CN_wordcount.csv', encoding = 'utf-8-sig', index = False)
# 이후 추가 불용어 확인

# %% [markdown]
# #### 2차 불용어 제거

# %%
# 불용어 list2
stop_word2 = ['안녕하세요', '이런', '입', '니다', '으로', '의', '을', '에', '를', '는', '이', '가', '에서', '은', '로', '및', '시',
        '인해', '고', '1', '과', '다', '있', '20', '시는', '500', '2', '와', 'do', 't',
        'c1', '0', '만', '10', '지', '3', '야', '인', '00', '또한', '에게', '4',
        '대', '서', '5', '01', '나', '있고', '되는', '6', '자', '될수', '들이', '80',
        '8', '된다', '12', '그', '됩니', '인근', '들어', '7', '게', '30', '것을', '위한',
        '하게', '02', '등을', '위해', '대한', '29', '위치하', '에는', '따라', '까', '9',
        '전', '것은', '하지', '여', '라는', '히', '라고', '중', '21', '일', '24', 'sp',
        '되지', '기', '요', '하며', '90', '내', '11', '더', '특히', '중에', '부터', '해서',
        '않고', '50', '15', '큰', '초', '19', '것이', '함', '중인', '많이', '아닌',
        '앞에', '모두', '라', '14', '이에', '나오는', '하도록', '이상의', '되도록', '들', '인데',
        '세', '니', 'qu', '명', '져', '제', '없을', 'ot', '있으며', '하', '28', '않은',
        '같은', '23', '에도', '첨부', '보아도', '시와', '이면', '들로', 'x', '60', '13',
        '사', '18', '저', '읍', '어느', '인한', 'nb', '할수', '31', 'po', '관련',
        '없다', 's', '아닙', '하면', '만큼', '곳이', '35', '만이', '하다', '있다고', '있음',
        '볼', '권', '240', '되고', '하는데', '지는', '간', '상', '곳에', '신', '36',
        '하기', 'p', '없', '곳을', '201', '였습니다', '또', '거', '25', '리가', '16',
        '클', '재', '안을', '원', '22', '정', '것입', '52', '잘', '해주', '이라도', '하십',
        '주시길', '09', '40', '주시', '86', '70', '이다', '45', '째', '그리고', '이고',
        '75', 'ma', '조차', '주세요', '들의', '와서', '되는데', 'KM', '있어서', '것과',
        '처럼', '중이며', '아니', '주고', '있으니', '만들', '미', '72', '그런', '그냥', '33',
        '합니', '92', '않', '성', '좀', '개가', '두고', 'SH', '말고', '6층', '42',
        '34', '데', '93', '66', 'G', '주십시오', '않을', '분', '08', '는데', '대로',
        '17', '되면', '73', '그러나', '별', '바로', '마시고', '32', 'm를', '63', '38',
        '뿐만', '무', '것에', '서야', '위하여', '둘러', '본', '이루어', '하라', '95', '등이',
        '가는', '55', '74', '했', '26', '65', '청', '아니고', '인이', '과의', '76',
        '과의', '76', '것이며', '하면서', '06', '서에', '새올', '등의', '받아', '돌아', '말이',
        '달라고', '이어', '져야', '겁니', '46', '지만', '78', '못', '이며', 'la', '07',
        'km', '56', '출', '이렇게', '마저도', '67', '하겠다는', '함을', '49', '53',
        '같다', '94', '41', '있으면', '거나', '두어', '27', '71', '그런데', '던', '77',
        '들과', '해주시길', '98', '202', '며', '만약', '부탁드', '저는', 'I', '들은',
        '하지만', '82', '들을', '99', '가서', '04', '1x', '62', 'ta', '염두에', '2x',
        '있었', '등과', '어', '아울러', '었', '인가요', '44', '758', '가지고', '아직', '음',
        '동안', '임', '이내로', '공', '47', '살', '89', 'C', '진다', '43', '있어야',
        'ㆍ', 'm', 'A', '37', '57', '확', '속히', '05', '회', '하시며', '엔', '있지',
        '서의', '등에', '없었', '010', '스스로', '다시한번', 'on', '성실히', '웬', '보듯',
        'A1', '다음에', '디어를', '끼친', '지요', '39', 're', '되야', '것보다', '때', '88',
        '86명', '쪽에', 'i', '그럼에도', '전에', '정확히', '54', '이라', '건가요', '대해',
        '④이', '①자', '②자', '③운', '간의', '창에', '길에', '우저', 'or', '다는', '97',
        '51', '없으니', '하시', '83', '대해서', 'g', '85', '58', '91', '84', '아무런',
        '건지', 'le', '난', '하였고', '만이라도', '여기', '되었는데', '단', '03', '했다',
        '자들', '라도', '59', '61', '따른', '인하여', '하세요', '인들의', '81', '하루라도',
        '안되', '가리', 'is', '하겠', '심', '했다고', '때문', '할것', '네요', '87', '바입',
        '1A', '한지', '1만', '79', '도록', '그러', 'me', '해결해', '나가는', '오는',
        '의하면', '익', '자를', '통하여', '입니', '경', '이니', '것도', 'ge', '겠', '함은',
        '과는', 'Sh', '많', '있으', 'ow', 'pG', '96', 'fi', '올', '들었', '24개',
        'S', 'st', '진', '으나', '부와', '오', 'D', '인은', '사는', '쪽', '아', '이게',
        '상에', '시고', '와의', '갈', 'in', '하였으나', '약3', '위를', '적이', '라면', '서는',
        '후에', '3x', '속에', 'MO', 'Na', '또다시', '단1', '당연히', '111', '나서',
        'yI', '1대', '했던', '않았', '로의', '든', '69', '결국', '하기의', '내가', '곧',
        '어제', '긴', '3월', '_', '번', '고를', '있게', '각각', '계속', '지어', '내서', '왔',
        '이로', '십', '물론', '제시하여야', '가당', '나온', '거쳐', '가고', '분들이', '이유는',
        '오히려', '되길', '나요', '하였음에도', '주요', '오로지', '그래서', '명이', '이유를', '하시는',
        '듯', '조', '걸로', '건은', '반', '하려', '위해서는', '기를', '덕분에', '으니', '좋겠',
        '에만', '져서', '하셔서', '하시나요', '할때', '민', '셔서', '치고', '데도', '받는',
        '다닐수', '구는', '하므로', '리', '대의', '선에', '려요', '주는', '오지', 'lo', '없도록',
        '뿐', '세요', '617', '없어서', '갈수', '않게', '부', '주실', '이었', '내고', '423',
        '낸', 'ad', '하오', '로서의', 'ce', '봅니다', '하네요', '다니', '한거', '1번', '점이',
        '해주십시오', '넣어', '나가', '어야', '였다', '하자', '142', '큽니다', '의해', '상당히',
        '이므', '하시길', '되', 'li', '한테', '인가', '임에도', '하려고', '번을', '결코', '토록',
        'led', '내는', '하였음', '그에', '죠', '게될', '하겠다고', '후에도', '해주십시요', 'pe',
        '보이고', '있기', '려고', 'p1', '사실을', '올립', '대부분이', '일부', '사실로', 'own',
        '것인가', '증', '라서', '없애', '실', '니까', 'd', '169', '점', '냐고', '즉',
        '이와', '간을', '있네', '씩', '자와', '하니', '작', '이내', '갔다', '려면', '려',
        '리겠', 'dog', '전혀', '하더라도', '래미', '등은', 'an', '다만', '체', '대부분의',
        '러', 'op', '아닐', '165', '시면', '파고', 'am', '있었는데', '무엇인지', '질문',
        '당신들', '하거', '기에', '모', '안된', '위해서도', '당시', '텐데', '올때', '그럼', '분명',
        '장은', '만을', '해줄', '원의', '언제까지', '노', '되었고', '나는', '주겠다고', '회를',
        '누구', '둡', '소', '화를', '권을', '건에', '해요', '491', '했음', '보기에도', '측',
        '뿐입니다', '때는', '것인데', '장을', '희', '있나요', '장이', '했지만', '차일피일', '질의',
        '이때', '이곳', '사이의', '인들', '구를', '467', 'E', '뒤에', '부분이', '극히',
        '있을까요', '함이', '커녕', '하루종일', '기존에', '였고', '써', '듯한', '위와', '아래의',
        '하십시오', '보지도', '경우에는', '제대로', '되었다고', '주십시요', '하였', '참', '있음을',
        '자세히', '마', '이러', '따르므로', '우', '빌', '어이가', '거는', '이나', '계속해서',
        '시로', 'r', 'e', '4개', '주', '속', '제2', '이들', 'the', '400', '되게',
        '냐', '마땅', '했는', '알려주', '바에', '수가', '데가', '6300', '레', 'b', 'c',
        '더니', '최', '701', '000', '는지', '제3자', '어요', '안하', '했다는', '들에',
        '어떠한', '랑', '1개', '열', '거기에', '하실', '나올', '이것', '명백히', '되므로',
        '부분은', 'to', '쯤', '으며', '362', '맞는', '못다', '가진', '는게', '그리', '저의',
        '할지', '첫', '월에', '원이', '년이', '951', '없으면', '루', '하시면', '관하여', '지면',
        'o', '값이', '수는', '되었다', 'gvnfD', '근처에', '저런', '합', '여러차례',
        '지금부터라도', '7013', '칩', '시점부터', '옵니다', '애초', '번에', '②', '다름이',
        '4개가', '등등', '겠다고', '13개', '했을', '듯이', '올초', '736', '코', '유의하여',
        '제1', '했기', '이래', '넘', '면을', '과와', '그럴', 'ti', '곳인데', '밑에', '데요',
        '인을', '높이', '질이', '측에', '그것도', '어디를', '다며', '없게', '것입니', 'of',
        '스런', '회가', '하나의', '비를', '899', '드디어', '무엇이', '되니', 'en', '혹은',
        '보지', '겸', '쪽은', '저렇게', '토', '여야', '서를', '많음', '레x', '없으며', '네',
        '한데', '내로', '따로', '아무리', '공문에', '외의', '661', '하십시요', '시일', '의한',
        '말씀을', '외에', '다면', '시간이면', '나지', '엄중히', 'de', '듯해서', '①', '되었으나',
        '이번에는', '수년', '통해서', '비해','습니다','합니다','있는','하고','하는','존경하는',
        '신고위치','제가','하여','2020','드렸','드립니다','한다','한','서울','되어']

# %%
df_CN.reset_index(inplace = True)
df_CN.head()

# %%
# 2차 불용어 제거
# 실제로는 파일이 너무 크기에 절반씩 나눠서 진행했음 
for i in range(0,df_CN.shape[0]) :
    if i%1000 == 0 :
        print(i)
    for j in range(len(df_CN['CN'][i])-1,-1,-1) : 
        if df_CN['CN'][i][j] in stop_word2:
            del(df_CN['CN'][i][j])

# %%
# 불용어 제거된 파일 저장
with open("df_CN_final.bin", "wb") as file:
    pickle.dump(df_CN, file)

# %% [markdown]
# # 날짜 기준으로 데이터 나누기

# %%
# structured file load
with open('dasan_structured.bin','rb') as f:
    df = pickle.load(f)

# %%
# 2019년과 2020년의 데이터만 추출
df2 = df[(df['datetime'].dt.year == 2020)|(df['datetime'].dt.year == 2019)]

# %%
# 구분 날짜
c_day = pd.to_datetime('2020-01-20') # 서울시 최초확진자 발생일, 12.31까지 347일
b_day = pd.to_datetime('2019-02-07') # 서울시 최초확진자 발생일로부터 347일 전

# %%
# 최초확진자 발생 전은 before, 발생 후는 after
list_c = []
for i in df2['datetime'] : 
    if i < c_day :
        list_c.append('before')
    else : 
        list_c.append('after')
        
df2['delimiter'] = list_c

# %%
# 불필요한 좌표컬럼 제거
df2 = df2.drop(['X','Y'], axis = 1)

# %%
df2.isnull().sum()
# Out:
# datetime         0
# ctype            0
# regist1          0
# regist2          0
# rdepart          0
# pdepart          0
# cate1            0
# cate2            0
# cate3            0
# dist1            0
# dist2            0
# regist_method    0
# delimiter        0
# dtype: int64

# %% [markdown]
# ### 대분류 유형 확인

# %%
df2['cate1'].value_counts()
# Out:
# 교통                    2858185
# 가로정비                   240986
# 청소                     189184
# 기타 불편사항                174681
# 환경/공원/상수도              146423
# 도로                     143190
# 환경                     115220
# 건설                      98982
# 주택/도시계획/부동산             93520
# 기타                      91851
# 보건                      68114
# 기획/감사/교육/정보화/마을공동체      49803
# 안전/소방/민방위               36360
# 주택건축                    35681
# 공원녹지                    33162
# 건강/식품위생                 26708
# 문화/관광/체육/디자인            26506
# 치수방재                    25466
# 코로나19                   16236
# 복지/어르신/장애인              13713
# 경제/일자리                   7226
# 여성/보육/아동 청소년             3709
#                          3175
# 세금/재정/계약                 2040
# 소방안전                      559
# 경제/산업                     345
# 신고(환경)                    182
# 범죄신고                      144
# Name: cate1, dtype: int64

# %% [markdown]
# #### 코로나19 대분류의 중분류 확인

# %%
df2.loc[df2['cate1'] == '코로나19','cate2'].value_counts()
# Out:
# 방역수칙미준수(개인 운송업종사자 등)    5585
# 다중이용시설이용제한              5283
# 기타                      4202
# 집합관련                     893
# 지원금                      273
# Name: cate2, dtype: int64

# %% [markdown]
# #### b데이부터 2020-12-31까지의 데이터만 사용

# %%
# b데이 이후의 민원데이터 날짜 기준으로 정렬
df_3 = df2.loc[df2['datetime'] > b_day,:].sort_values(by = 'datetime') 
# 데이터 저장
with open( "dasan_structured_final.bin", "wb" ) as file:
    pickle.dump(df_3, file)

# %%
# 데이터 불러오기
with open('dasan_structured_final.bin','rb') as f:
    df4 = pickle.load(f)

# %% [markdown]
# #### 코로나 대분류의 세부 카테고리 통계량

# %%
df4 = df4.loc[df4['cate1'] == '코로나19',['cate2','cate3']].value_counts().reset_index()
df4.columns = ['cate2','cate3','count']
df5 = df4.sort_values(by = ['cate2','count'], ascending = False)

# %%
df5
# Out:
#                    cate2                             cate3  count
# 9                   집합관련                  행사(전시회 박람회 집회 등)    572
# 16                  집합관련               사적모임(결혼식 동호회 장례식 등)    172
# 20                  집합관련               각종시험(채용시험 자격증 시험 등)    149
# 23                   지원금                         자영업자 생존자금     77
# 25                   지원금                                기타     67
# 27                   지원금                       정부 긴급재난 지원금     42
# 30                   지원금                      서울시 긴급재난 지원금     33
# 33                   지원금                    외국인 재난긴급생활비 지원     27
# 34                   지원금                          프리랜서 지원금     27
# 0   방역수칙미준수(개인 운송업종사자 등)                           마스크 미착용   4827
# 5   방역수칙미준수(개인 운송업종사자 등)                                기타    734
# 35  방역수칙미준수(개인 운송업종사자 등)                       자가격리자 이탈 행위     24
# 1             다중이용시설이용제한                 (의무화시설) 일반· 휴게음식점   1510
# ...

# %%
# 저장
df4.loc[df4['cate1'] == '코로나19',:].to_csv('cate1_covid.csv', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # 증감률 큰 분류 확인

# %%
# text file load
with open('df_CN_final.bin','rb') as f:
    df_text = pickle.load(f)

# %%
# structured file load
with open('dasan_structured_final.bin','rb') as f:
    df_stru = pickle.load(f)

# %%
# text와 structured 파일 조인 후 전/후 분리
df_total = pd.merge(df_text, df_stru, left_index = True, right_index = True)
df_total['date'] = df_total['datetime'].apply(lambda x : datetime.strftime(x,'%Y-%m-%d'))

df_before = df_total[(df_total['delimiter'] == 'before')]
df_after = df_total[(df_total['delimiter'] == 'after')]

# %%
# 증감률이 가장 큰 5개의 카테고리만 따로 저장
df2[(df2['cate1'] == '건강/식품위생')|
    (df2['cate1'] == '경제/산업')|
    (df2['cate1'] == '경제/일자리')|
    (df2['cate1'] == '복지/어르신/장애인')|
    (df2['cate1'] == '문화/관광/체육/디자인')].to_csv('after_증감률.csv', encoding = 'utf-8-sig', index = False)

# %%
from datetime import datetime

# %% [markdown]
# #### 전년 동기와 민원량 비교

# %%
df_before.loc[(df_before['date'].str[:7] == '2019-05')&(df_before['cate1'] == '문화/관광/체육/디자인'),'cate2'].value_counts()
# Out:
# 문화예술        252
# 체육          137
# 디자인         132
# 전통문화/문화재     42
# 관광           27
# 문화정책         24
# 문화산업          9
# Name: cate2, dtype: int64

# %%
df_after.loc[(df_after['date'].str[:7] == '2020-05')&(df_after['cate1'] == '문화/관광/체육/디자인'),'cate2'].value_counts()
# Out:
# 문화정책        978
# 디자인         129
# 문화예술         94
# 체육           74
# 전통문화/문화재     16
# 관광           13
# 문화산업          2
# Name: cate2, dtype: int64

# %%
df_before.loc[(df_before['date'].str[:7] == '2019-04')&(df_before['cate1'] == '복지/어르신/장애인'),'cate2'].value_counts()
# Out:
# 장애인복지     227
# 복지정책       46
# 어르신복지      39
# 복지취약계층     28
# 노숙인복지      24
# Name: cate2, dtype: int64

# %%
df__after.loc[(df_after['date'].str[:7] == '2020-04')&(df_after['cate1'] == '복지/어르신/장애인'),'cate2'].value_counts()
# Out:
# 복지취약계층    1652
# 장애인복지      261
# 복지정책       116
# 어르신복지       47
# 노숙인복지       19
# Name: cate2, dtype: int64

# %%
df_before.loc[(df_before['date'].str[:7] == '2019-05')&(df_before['cate1'] == '복지/어르신/장애인'),'cate2'].value_counts()
# Out:
# 장애인복지     202
# 복지정책       73
# 어르신복지      38
# 복지취약계층     32
# 노숙인복지      15
# Name: cate2, dtype: int64

# %%
df_after.loc[(df_after['date'].str[:7] == '2020-05')&(df_after['cate1'] == '복지/어르신/장애인'),'cate2'].value_counts()
# Out:
# 복지취약계층    1217
# 장애인복지      262
# 복지정책        69
# 어르신복지       47
# 노숙인복지       17
# Name: cate2, dtype: int64

# %%
df4.iloc[:,:13].to_csv('after.csv', index=  False,encoding = 'utf-8-sig')

# %% [markdown]
# # 중분류 복지취약계층 확인

# %%
import pandas as pd
import dask as dd
import pickle
from datetime import datetime

# %%
with open('dasan_structured_final.bin','rb') as f:
    df1 = pickle.load(f)

# %%
with open('df_CN_stopword_final.bin','rb') as f:
    df2 = pickle.load(f)

# %%
df1['date'] = df1['datetime'].apply(lambda x : datetime.strftime(x,'%Y-%m-%d'))

# %%
df1 = df1.loc[(df1['cate2'] == '복지취약계층')&(df1['delimiter'] == 'after'),:]

# %%
복지_index = list(df1.loc[((df1['date'].str[:7] == '2020-04')|(df1['date'].str[:7] == '2020-05')),:].index)

# %%
df2.loc[복지_index,'CN'].apply(lambda x : ' '.join(x)).to_csv('복지취약계층_4-5월.csv', encoding = 'utf-8-sig')

# %% [markdown]
# # 중분류 문화정책 확인

# %%
문화정책_index = list(df1.loc[(df1['cate2'] == '문화정책')&(df1['delimiter'] == 'after')&(df1['date'].str[:7] == '2020-05'),:].index)

# %%
df2.loc[문화정책_index, 'CN'].apply(lambda x : ' '.join(x)).to_csv('문화정책_5월.csv', encoding = 'utf-8-sig')

# %%
df1.loc['13830468',:]
# Out:
# datetime         2020-05-28 14:04:55
# ctype                           일반민원
# regist1                        다산콜재단
# regist2                     120 전화상담
# rdepart              시민소통기획관 시민봉사담당관
# pdepart          복지정책실 복지기획관 지역돌봄복지과
# cate1                     복지/어르신/장애인
# cate2                         복지취약계층
# cate3                      어려운 이웃 지원
# dist1                             본청
# dist2                        본청(서울시)
# regist_method                    인터넷
# delimiter                      after
# Name: 13830468, dtype: object
